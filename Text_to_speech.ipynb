# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhasri28/SDC-Activities/blob/main/Text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyttsx3

# %%
# !pip install gTTS

# %%
from gtts import gTTS
import os
from IPython.display import Audio

def text_to_speech(text):
    # Convert the text to speech using Google TTS
    tts = gTTS(text=text, lang='en')

    # Save the audio to a file
    tts.save("output.mp3")

    # Display the audio player in Colab
    return Audio("output.mp3", autoplay=True)

# Example usage
text = "Hello Suhasri, Happy Mourning"
text_to_speech(text)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
