# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhasri28/SDC-Activities/blob/main/Using%20API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Deep Learning

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 📊 Sample data
data = {
    'Bedrooms': [3, 4, 2, 5, 3, 6, 4, 2, 3, 5],
    'Bathrooms': [2, 3, 1, 4, 2, 5, 3, 1, 2, 4],
    'Area': [1500, 2500, 1200, 3000, 1600, 3200, 2600, 1100, 1700, 3100],
    'LocationScore': [8, 9, 7, 10, 8, 10, 9, 6, 7, 10],
    'Price': [300000, 500000, 200000, 600000, 320000, 650000, 510000, 180000, 340000, 620000]
}

df = pd.DataFrame(data)

# ✅ Split features and target
X = df[['Bedrooms', 'Bathrooms', 'Area', 'LocationScore']]
y = df['Price']

# 🔧 Scale features
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# 🔧 Scale target
scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

# 🧪 Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# 🧠 Build the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer
])

model.compile(optimizer='adam', loss='mean_squared_error')

# 🏋️ Train the model
model.fit(X_train, y_train, epochs=100, batch_size=2, verbose=0)

# 📥 Get user input
print("Enter house details to predict the price:")
bedrooms = int(input("Number of bedrooms: "))
bathrooms = int(input("Number of bathrooms: "))
area = int(input("Area in square feet: "))
location_score = int(input("Location score (1-10): "))

# 🔍 Predict
user_input = np.array([[bedrooms, bathrooms, area, location_score]])
user_scaled = scaler_X.transform(user_input)
predicted_scaled = model.predict(user_scaled)
predicted_price = scaler_y.inverse_transform(predicted_scaled)[0][0]

print(f"\nEstimated House Price: ${predicted_price:,.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Enter house details to predict the price:
# Number of bedrooms: 4
# Number of bathrooms: 3
# Area in square feet: 3450
# Location score (1-10): 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#
# Estimated House Price: $435,013.50
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Gen - AI Language Transalator

# %%
# !pip install google-generativeai

# %%
# !pip install google-generativeai

# %%
# !pip install --upgrade google-generativeai

# %%
import google.generativeai as genai

# Configure the API key
genai.configure(api_key="AIzaSyDFli0VEiN7WUK49LtywFJkjLBiAKv-gvU")

# Select the free model (gemini-1.5-flash or other model)
model = genai.GenerativeModel("gemini-1.5-flash")

def translate_text(text, source_lang="English", target_lang="Tamil"):
    # Generate the prompt for translation
    prompt = f"Translate the following text from {source_lang} to {target_lang}:\n\n{text}"

    # Get the translation response
    response = model.generate_content(prompt)

    # Return the translated text
    return response.text.strip()

# Example usage
text_to_translate = """Hello World, Linear regression is used for predicting values"""
source_language = "English"
target_language = "Tamil"

# Translate the text
translated_text = translate_text(text_to_translate, source_lang=source_language, target_lang=target_language)

# Print the translated text
print(f"Translated Text from {source_language} to {target_language}:\n", translated_text)
# Out:
# Translated Text from English to Tamil:
#  வணக்கம் உலகே,  நேரியல் பின்னடைவு மதிப்புகளை கணிக்கப் பயன்படுகிறது.
#
#
# (Vaṇakkam ulagē, nēriyal pinnadaivu maṭippukaளை kaṇikkka pāyaṇpaṭukiratu.)

# %%
Summarizer

# %%
import google.generativeai as genai

# Configure API key
genai.configure(api_key="AIzaSyDFli0VEiN7WUK49LtywFJkjLBiAKv-gvU")

# Select free model
model = genai.GenerativeModel("gemini-1.5-flash")

def summarize_text(text):
    response = model.generate_content(f"Summarize this text:\n\n{text}")
    return response.text

# Example usage
text_to_summarize = """Hi, I am suhasri...Mango is yellow in colour, Linear regression, Linear algebra is my favourite subject, FST is tough, AI seems interestoing"""
summary = summarize_text(text_to_summarize)
print("Summary:\n", summary)
# Out:
# Summary:
#  Suhasri enjoys linear algebra and finds AI interesting, but finds FST difficult.  She also notes that mangoes are yellow.

# %%
ChatBot

# %%
import google.generativeai as genai

# Configure the API key
genai.configure(api_key="AIzaSyDFli0VEiN7WUK49LtywFJkjLBiAKv-gvU")

# Select the free model (gemini-1.5-flash or any available model)
model = genai.GenerativeModel("gemini-1.5-flash")

def chatbot_response(user_input):
    # Generate a response prompt for the chatbot
    prompt = f"You are a helpful and friendly chatbot. Respond to the user's question or statement:\n\n{user_input}"

    # Get the chatbot's response
    response = model.generate_content(prompt)

    # Return the chatbot's reply
    return response.text.strip()

# Example conversation
print("✨ Welcome to the Chatbot! ✨\nType 'exit' to end the conversation.")

while True:
    # Get user input
    user_input = input("\nYou: ")

    # Exit the chatbot if user types 'exit'
    if user_input.lower() == 'exit':
        print("Goodbye! 👋")
        break

    # Get chatbot response
    response = chatbot_response(user_input)

    # Print the chatbot's response
    print(f"Bot: {response}")
# Out:
# ✨ Welcome to the Chatbot! ✨
# Type 'exit' to end the conversation.
#
# You: Hello
# Bot: Hello there! How can I help you today?
#
# You: Nothing
# Bot: Is there anything I can help you with today?  Let me know if you change your mind! 😊
#
# You: exit
# Goodbye! 👋

# %%
Text To speech

# %%
# !pip install pyttsx3

# %%
import pyttsx3

def text_to_speech(text):
    # Initialize the TTS engine
    engine = pyttsx3.init()

    # Set properties (optional)
    engine.setProperty('rate', 150)  # Speed of speech
    engine.setProperty('volume', 1)  # Volume (0.0 to 1.0)

    # Convert the text to speech
    engine.say(text)

    # Wait for the speech to finish before closing
    engine.runAndWait()

# Example usage
text = input("Enter the text to convert to speech: ")
text_to_speech(text)
# Out:
# Enter the text to convert to speech: Hello World
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pyttsx3/__init__.py in init(driverName, debug)
#      19     try:
# ---> 20         eng = _activeEngines[driverName]
#      21     except KeyError:
#
# /usr/lib/python3.11/weakref.py in __getitem__(self, key)
#     135             self._commit_removals()
# --> 136         o = self.data[key]()
#     137         if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-cf3c2542b464> in <cell line: 0>()
#      17 # Example usage
#      18 text = input("Enter the text to convert to speech: ")
# ---> 19 text_to_speech(text)
#
# <ipython-input-18-cf3c2542b464> in text_to_speech(text)
# ...

# %%
# !pip install gTTS

# %%
from gtts import gTTS
import os

def text_to_speech(text, lang="en"):
    # Initialize the TTS engine
    tts = gTTS(text=text, lang=lang, slow=False)

    # Save the audio to a file
    tts.save("output.mp3")

    # Play the audio
    os.system("start output.mp3")  # For Windows
    # os.system("mpg321 output.mp3")  # For Linux/macOS (use mpg321 or similar)

# Example usage
text = input("Enter the text to convert to speech: ")
text_to_speech(text)
# Out:
# Enter the text to convert to speech: hello

# %%
from gtts import gTTS
import os
import time

def text_to_speech(text, lang="en"):
    # Initialize the TTS engine
    tts = gTTS(text=text, lang=lang, slow=False)

    # Save the audio to a file
    tts.save("output.mp3")

    # Try playing the audio (platform-specific)
    try:
        if os.name == 'nt':  # For Windows
            os.system("start output.mp3")
        elif os.name == 'posix':  # For Linux/macOS
            os.system("mpg321 output.mp3")  # Use mpg321 or other available players
        time.sleep(2)  # Give time for audio to play
    except Exception as e:
        print(f"Error during audio playback: {e}")

# Example usage
text = input("Enter the text to convert to speech: ")
text_to_speech(text)
# Out:
# Enter the text to convert to speech: Hello
