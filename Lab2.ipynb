# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhasri28/SDC-Activities/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Generate a python program that uses CAN to classify images'

# Install necessary libraries
# !pip install can

import can
import numpy as np
from PIL import Image
import os

# Assuming you have a trained CAN model saved as 'can_model.h5'
# Replace this with your actual model loading code
# For example, if using TensorFlow/Keras:
# from tensorflow import keras
# model = keras.models.load_model('can_model.h5')

# Define the image preprocessing function
def preprocess_image(image_path):
  try:
    img = Image.open(image_path).convert('RGB')  # Ensure RGB format
    img = img.resize((224, 224))  # Resize to match model input
    img_array = np.array(img) / 255.0  # Normalize pixel values
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array
  except FileNotFoundError:
    print(f"Error: Image file not found at {image_path}")
    return None
  except Exception as e:
    print(f"Error processing image: {e}")
    return None

# Function to classify an image using the CAN model
def classify_image(image_path):
  preprocessed_image = preprocess_image(image_path)
  if preprocessed_image is not None:
      # Replace with your actual model prediction code
      # For example, if using TensorFlow/Keras:
      # predictions = model.predict(preprocessed_image)
      # predicted_class = np.argmax(predictions)
      # Replace with actual class labels
      # print(f"Predicted class: {predicted_class}")

      # Placeholder for CAN classification results
      # Replace with your actual CAN model prediction logic
      print("This is where the CAN model prediction would occur.")
      predicted_class = "Placeholder Class"  # Placeholder
      confidence = 0.8  # Placeholder

      return predicted_class, confidence
  return None, None # Return None if the image could not be loaded.


# Example usage
image_folder = 'images'  # Replace with your image folder
if not os.path.exists(image_folder):
  os.makedirs(image_folder)  # Create the folder if it does not exist
  print("Created image folder") # Let the user know that the folder was created.


image_files = [f for f in os.listdir(image_folder) if os.path.isfile(os.path.join(image_folder, f))]


for image_file in image_files:
  image_path = os.path.join(image_folder, image_file)
  predicted_class, confidence = classify_image(image_path)
  if predicted_class is not None:
    print(f"Image: {image_file}, Predicted class: {predicted_class}, Confidence: {confidence}")

# Note:  This requires you to replace the placeholder comments with
# actual model loading and prediction code using your chosen deep learning framework (TensorFlow, PyTorch etc.)
# and your trained CAN model.

# %%
# prompt: Generate a simple python code using RNN

import numpy as np
import tensorflow as tf

# Define the RNN model
model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(64, activation='relu', input_shape=(None, 1)),  # Input shape: (timesteps, features)
    tf.keras.layers.Dense(1)  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Generate sample data
timesteps = 10
data_points = 100
X = np.random.rand(data_points, timesteps, 1)  # Input data
y = np.sum(X, axis=1)  # Target output (sum of each sequence)


# Train the model
model.fit(X, y, epochs=10)

# Make predictions
new_data = np.random.rand(1, timesteps, 1)
predictions = model.predict(new_data)

print(f"Predictions : {predictions}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 22.8715
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.4030
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.2093
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.0336
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 11.8263
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.8870
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3644
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3592
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8131
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6381
# ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms-spam-collection.csv", encoding='latin-1')
df.columns = ["label", "message"]

# Encode labels (ham -> 0, spam -> 1)
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

# Tokenization
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(df['message'])
sequences = tokenizer.texts_to_sequences(df['message'])
padded_sequences = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['label'], test_size=0.2, random_state=42)

# Build ANN model
model = Sequential([
    Embedding(input_dim=5000, output_dim=16, input_length=100),
    GlobalAveragePooling1D(),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-c92f3dee62d2> in <cell line: 0>()
#      11
#      12 # Load dataset
# ---> 13 df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms-spam-collection.csv", encoding='latin-1')
#      14 df.columns = ["label", "message"]
#      15
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-32aef03e-b603-4533-a1c7-8dd216160500" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32aef03e-b603-4533-a1c7-8dd216160500">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
df = pd.read_csv("spam.csv", encoding='latin-1')
#df.columns = ["label", "message"]

# Encode labels (ham -> 0, spam -> 1)
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

# Tokenization
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(df['message'])
sequences = tokenizer.texts_to_sequences(df['message'])
padded_sequences = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['label'], test_size=0.2, random_state=42)

# Build ANN model
model = Sequential([
    Embedding(input_dim=5000, output_dim=16, input_length=100),
    GlobalAveragePooling1D(),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-0f347fff6e2b> in <cell line: 0>()
#      16 # Encode labels (ham -> 0, spam -> 1)
#      17 le = LabelEncoder()
# ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
df = pd.read_csv("spam.csv", encoding='latin-1')

# Inspect dataset columns
print(df.head())

# Drop unnecessary columns
df = df.iloc[:, [0, 1]]  # Keep only the first two columns
df.columns = ["label", "message"]  # Rename columns properly

# Encode labels (ham -> 0, spam -> 1)
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

# Tokenization
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(df['message'])
sequences = tokenizer.texts_to_sequences(df['message'])
padded_sequences = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['label'], test_size=0.2, random_state=42)

# Build ANN model
model = Sequential([
    Embedding(input_dim=5000, output_dim=16, input_length=100),
    GlobalAveragePooling1D(),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8383 - loss: 0.4392 - val_accuracy: 0.8655 - val_loss: 0.3677
# Epoch 2/10
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2

# Load dataset (e.g., MNIST for simplicity)
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize and reshape data
x_train = x_train / 255.0
x_test = x_test / 255.0
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Build CNN model
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile and train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# Save model
model.save("cnn_image_classifier.h5")

print("Model saved successfully!")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 67s 35ms/step - accuracy: 0.9079 - loss: 0.2941 - val_accuracy: 0.9819 - val_loss: 0.0544
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 57s 30ms/step - accuracy: 0.9854 - loss: 0.0454 - val_accuracy: 0.9891 - val_loss: 0.0344
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 85s 32ms/step - accuracy: 0.9910 - loss: 0.0280 - val_accuracy: 0.9876 - val_loss: 0.0376
# Epoch 4/5

# %%
# !pip install tensorflow numpy opencv-python matplotlib

# %%
# Load dataset (e.g., MNIST for digit classification)
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize data (0 to 1 scale)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN (28x28 grayscale images)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Build CNN model
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')  # 10 classes (digits 0-9)
])

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# Save the trained model
model.save("cnn_image_classifier.h5")
print("Model saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a8e829da0d9> in <cell line: 0>()
#       1 # Load dataset (e.g., MNIST for digit classification)
# ----> 2 mnist = keras.datasets.mnist
#       3 (x_train, y_train), (x_test, y_test) = mnist.load_data()
#       4
#       5 # Normalize data (0 to 1 scale)
#
# NameError: name 'keras' is not defined

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Load MNIST dataset (handwritten digits)
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values (0 to 1 scale)
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN input (28x28 grayscale images)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Build CNN model
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')  # 10 output classes (digits 0-9)
])

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# Save trained model
model.save("cnn_image_classifier.h5")
print("Model saved successfully!")

# Function to classify uploaded image
def classify_uploaded_image():
    uploaded = files.upload()  # Upload image
    for filename in uploaded.keys():
        # Load image using OpenCV
        img = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (28, 28))  # Resize to match MNIST input size
        img = img / 255.0  # Normalize pixel values
        img = img.reshape(1, 28, 28, 1)  # Reshape for CNN input

        # Predict
        prediction = model.predict(img)
        predicted_label = np.argmax(prediction)

        # Display image and prediction
        plt.imshow(img.reshape(28,28), cmap='gray')
        plt.title(f"Predicted Digit: {predicted_label}")
        plt.axis('off')
        plt.show()

# Call this function after training to classify an uploaded image
classify_uploaded_image()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 61s 32ms/step - accuracy: 0.9176 - loss: 0.2764 - val_accuracy: 0.9857 - val_loss: 0.0450
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 79s 30ms/step - accuracy: 0.9866 - loss: 0.0434 - val_accuracy: 0.9875 - val_loss: 0.0362
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 30ms/step - accuracy: 0.9919 - loss: 0.0260 - val_accuracy: 0.9890 - val_loss: 0.0333
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 63s 34ms/step - accuracy: 0.9934 - loss: 0.0207 - val_accuracy: 0.9916 - val_loss: 0.0277
# Epoch 5/5
# ...
